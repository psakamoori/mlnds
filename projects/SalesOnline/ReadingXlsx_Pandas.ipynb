# %% [markdown]
# # Visualizing retail sales usning Pandas (xlsx)

# %%
import pandas as pd
import numpy as np
# %matplotlib  inline
import matplotlib.pyplot as plt
#import time
from datetime import datetime
from pandas import DataFrame

# %%
dFrame = pd.read_excel('../../data/xlsx/Online_Retail.xlsx')
df = dFrame

# %%
dFrame
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
dFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null datetime64[ns]
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
dFrame.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
type(dFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
df = dFrame.set_index("InvoiceDate")

# %%
# Convert df from string to date and ti,me
df.index = df.index.to_datetime()

# %%
df.index
# Out:
# DatetimeIndex(['2010-12-01 08:26:00', '2010-12-01 08:26:00',
#                '2010-12-01 08:26:00', '2010-12-01 08:26:00',
#                '2010-12-01 08:26:00', '2010-12-01 08:26:00',
#                '2010-12-01 08:26:00', '2010-12-01 08:28:00',
#                '2010-12-01 08:28:00', '2010-12-01 08:34:00',
#                ...
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00'],
#               dtype='datetime64[ns]', name=u'InvoiceDate', length=541909, freq=None)

# %%
dFrame["InvoiceDate"] = pd.to_datetime(dFrame["InvoiceDate"])

# %%
dFrame.index = dFrame["InvoiceDate"]

# %%
del dFrame["InvoiceDate"]

# %%
dFrame
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 2010-12-01 08:26:00    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 2010-12-01 08:26:00    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 2010-12-01 08:28:00    536366     22633               HAND WARMER UNION JACK
# 2010-12-01 08:28:00    536366     22632            HAND WARMER RED POLKA DOT
# 2010-12-01 08:34:00    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
# 2010-12-01 08:34:00    536367     22745           POPPY'S PLAYHOUSE BEDROOM
# ...

# %%
#dF = pd.DataFrame.from_records(dFrame, columns=['CustomerID', 'Quantity'], index=dFrame.index)
dF = pd.DataFrame.from_records(dFrame, columns=['Quantity'], index=dFrame['CustomerID'])
#dFrame.plot(x=dFrame['CustomerID'], y=dFrame['Quantity'])
dF['Quantity'].plot()

# %%
# Observations in specific Year
dFrame['2010']
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 2010-12-01 08:26:00    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 2010-12-01 08:26:00    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 2010-12-01 08:28:00    536366     22633               HAND WARMER UNION JACK
# 2010-12-01 08:28:00    536366     22632            HAND WARMER RED POLKA DOT
# 2010-12-01 08:34:00    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
# 2010-12-01 08:34:00    536367     22745           POPPY'S PLAYHOUSE BEDROOM
# ...

# %%
# Observations in specific Year and Month
dFrame['2010-12']
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 2010-12-01 08:26:00    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 2010-12-01 08:26:00    536365     21730    GLASS STAR FROSTED T-LIGHT HOLD
# ...

# %%
# Per day sales
dFrame.resample('D').sum()
# Out:
#              Quantity  UnitPrice  CustomerID
# InvoiceDate
# 2010-12-01    26814.0   12904.25  30821613.0
# 2010-12-02    21023.0    6815.68  32921050.0
# 2010-12-03    14830.0   11114.09  17091533.0
# 2010-12-04        NaN        NaN         NaN
# 2010-12-05    16395.0    7893.17  41415197.0
# 2010-12-06    21419.0   17678.78  31409278.0
# 2010-12-07    24995.0   85152.09  17493785.0
# 2010-12-08    22741.0    9978.06  31440141.0
# 2010-12-09    18431.0   14662.63  28207132.0
# 2010-12-10    20297.0   12825.06  22367233.0
# 2010-12-11        NaN        NaN         NaN
# 2010-12-12    10565.0    3966.23  22953656.0
# 2010-12-13    17623.0   12388.27  20021527.0
# 2010-12-14    20098.0    8257.36  26085048.0
# 2010-12-15    18229.0    4819.31  20646877.0
# 2010-12-16    29632.0    5954.72  26451538.0
# 2010-12-17    16069.0   18131.21  10540957.0
# 2010-12-18        NaN        NaN         NaN
# 2010-12-19     3795.0    1640.19   8117744.0
# ...

# %%
dFrame.resample('D').sum().plot()

# %%
 #for q in dFrame['Quantity']:
 #   print q
 #   if q < 0:
 #       dFrame['Quantity'] = int(0)

# %%
#dFrame.resample('D').sum()

# %%
# Creating a temp data frame (df)
#df = DataFrame({'Date': dFrame.index, 'Quantity':dFrame['Quantity'], 'CustomerID':dFrame['CustomerID']})
df = DataFrame({'Quantity':dFrame['Quantity'], 'CustomerID':dFrame['CustomerID']})

# %%
df
# Out:
#                      CustomerID  Quantity
# InvoiceDate
# 2010-12-01 08:26:00     17850.0         6
# 2010-12-01 08:26:00     17850.0         6
# 2010-12-01 08:26:00     17850.0         8
# 2010-12-01 08:26:00     17850.0         6
# 2010-12-01 08:26:00     17850.0         6
# 2010-12-01 08:26:00     17850.0         2
# 2010-12-01 08:26:00     17850.0         6
# 2010-12-01 08:28:00     17850.0         6
# 2010-12-01 08:28:00     17850.0         6
# 2010-12-01 08:34:00     13047.0        32
# 2010-12-01 08:34:00     13047.0         6
# 2010-12-01 08:34:00     13047.0         6
# 2010-12-01 08:34:00     13047.0         8
# 2010-12-01 08:34:00     13047.0         6
# 2010-12-01 08:34:00     13047.0         6
# 2010-12-01 08:34:00     13047.0         3
# 2010-12-01 08:34:00     13047.0         2
# 2010-12-01 08:34:00     13047.0         3
# 2010-12-01 08:34:00     13047.0         3
# 2010-12-01 08:34:00     13047.0         4
# 2010-12-01 08:34:00     13047.0         4
# ...

# %%
#for idx in df.index:
#    if df.loc[idx]['Quantity'] == 'nan':#:'2011-12-09']:
#        df.loc['Quantity'] = 0
#    if df.loc[idx]['UnitPrice'] == 'nan':#:'2011-12-09']:
#        df.loc['UnitPrice'] = 0
#    if df.loc[idx]['CustomerID'] == 'nan':#:'2011-12-09']:
#        df.loc['CustomerID'] = 0
    #print ind

# %%
df_cid = df.groupby('CustomerID')

# %%
df_cid.describe()
# Out:
#            Quantity                                                       \
#               count        mean            std      min       25%    50%
# CustomerID
# 12346.0         2.0    0.000000  104955.859532 -74215.0 -37107.50    0.0
# 12347.0       182.0   13.505495      18.856172      2.0      6.00   12.0
# 12348.0        31.0   75.516129      51.091990      1.0     24.00   72.0
# 12349.0        73.0    8.643836       6.982856      1.0      4.00    6.0
# 12350.0        17.0   11.588235       4.345383      1.0     12.00   12.0
# 12352.0        95.0    4.947368       5.990007    -12.0      2.00    4.0
# 12353.0         4.0    5.000000       2.581989      2.0      3.50    5.0
# 12354.0        58.0    9.137931       8.832651      1.0      3.00    6.0
# 12355.0        13.0   18.461538      27.978013      2.0      6.00    6.0
# 12356.0        59.0   26.966102      24.624046      2.0     12.00   24.0
# 12357.0       131.0   20.671756      16.324801      1.0     12.00   16.0
# ...

# %%
#df_cid.plot(kind='Scatter', x="CustomerId'", y="Quantity")
#df_cid.plot()

# %%
#data = pd.DataFrame.from_records(df_cid, columns=['Quantity'], index='CustomerID')
#data = pd.DataFrame.from_records(dFrame, columns=['Quantity'], index='InvoiceDate')
#df_cid.index = df_cid['CustomerID']

# %%
#data['Quantity'].plot()

# %%
#df_cid

# %%
#df_cid.plot(x='CustomerID', y='Quantity')
#df_cid['Quantity'].plot()
# Out:
# CustomerID
# 12346.0    Axes(0.125,0.2;0.775x0.68)
# 12347.0    Axes(0.125,0.2;0.775x0.68)
# 12348.0    Axes(0.125,0.2;0.775x0.68)
# 12349.0    Axes(0.125,0.2;0.775x0.68)
# 12350.0    Axes(0.125,0.2;0.775x0.68)
# 12352.0    Axes(0.125,0.2;0.775x0.68)
# 12353.0    Axes(0.125,0.2;0.775x0.68)
# 12354.0    Axes(0.125,0.2;0.775x0.68)
# 12355.0    Axes(0.125,0.2;0.775x0.68)
# 12356.0    Axes(0.125,0.2;0.775x0.68)
# 12357.0    Axes(0.125,0.2;0.775x0.68)
# 12358.0    Axes(0.125,0.2;0.775x0.68)
# 12359.0    Axes(0.125,0.2;0.775x0.68)
# 12360.0    Axes(0.125,0.2;0.775x0.68)
# 12361.0    Axes(0.125,0.2;0.775x0.68)
# 12362.0    Axes(0.125,0.2;0.775x0.68)
# 12363.0    Axes(0.125,0.2;0.775x0.68)
# 12364.0    Axes(0.125,0.2;0.775x0.68)
# 12365.0    Axes(0.125,0.2;0.775x0.68)
# 12367.0    Axes(0.125,0.2;0.775x0.68)
# 12370.0    Axes(0.125,0.2;0.775x0.68)
# 12371.0    Axes(0.125,0.2;0.775x0.68)
# 12372.0    Axes(0.125,0.2;0.775x0.68)
# 12373.0    Axes(0.125,0.2;0.775x0.68)
# ...

# %%
#dFrame.resample('D').sum().plot(kind='Scatter', x=df.index, y=dFrame['Quantity'])
#df.plot.kde()
#pd.plotting.scatter_matrix(df)
#df['2010-12-01':'2011-12-09'].plot()
