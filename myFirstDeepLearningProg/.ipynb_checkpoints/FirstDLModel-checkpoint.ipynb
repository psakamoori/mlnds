# %% [markdown]
# # First Deep Learning Model

# %%
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples = 500, 
                    noise = 0.1, 
                    factor = 0.2, 
                    random_state=0)

# %%
X.shape
# Out:
# (500, 2)

# %%
plt.figure(figsize=(8,8))
plt.plot(X[y==0, 0], X[y==0, 1], 'og', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], '+b', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Green circles and blue plus")

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=25)
# Out:
# Epoch 1/25
# 500/500 [==============================] - 0s - loss: 0.6999 - acc: 0.5480
# Epoch 2/25
# 500/500 [==============================] - 0s - loss: 0.6862 - acc: 0.6360
# Epoch 3/25
# 500/500 [==============================] - 0s - loss: 0.6732 - acc: 0.7360
# Epoch 4/25
# 500/500 [==============================] - 0s - loss: 0.6506 - acc: 0.7300
# Epoch 5/25
# 500/500 [==============================] - 0s - loss: 0.6194 - acc: 0.8000
# Epoch 6/25
# 500/500 [==============================] - 0s - loss: 0.5727 - acc: 0.8720
# Epoch 7/25
# 500/500 [==============================] - 0s - loss: 0.5236 - acc: 0.8360
# Epoch 8/25
# 500/500 [==============================] - 0s - loss: 0.4770 - acc: 0.8480
# Epoch 9/25
# 500/500 [==============================] - 0s - loss: 0.4336 - acc: 0.8700
# Epoch 10/25
# 500/500 [==============================] - 0s - loss: 0.3956 - acc: 0.8700
# Epoch 11/25
# 500/500 [==============================] - 0s - loss: 0.3622 - acc: 0.8800
# Epoch 12/25
# 500/500 [==============================] - 0s - loss: 0.3287 - acc: 0.8860
# Epoch 13/25
# 500/500 [==============================] - 0s - loss: 0.2947 - acc: 0.8980
# Epoch 14/25
# 500/500 [==============================] - 0s - loss: 0.2579 - acc: 0.9360
# Epoch 15/25
# 500/500 [==============================] - 0s - loss: 0.2252 - acc: 0.9780
# Epoch 16/25
# 500/500 [==============================] - 0s - loss: 0.1934 - acc: 0.9980
# Epoch 17/25
# 500/500 [==============================] - 0s - loss: 0.1702 - acc: 1.0000
# Epoch 18/25
# 500/500 [==============================] - 0s - loss: 0.1508 - acc: 1.0000
# Epoch 19/25
# 500/500 [==============================] - 0s - loss: 0.1345 - acc: 1.0000
# Epoch 20/25
# 500/500 [==============================] - 0s - loss: 0.1217 - acc: 1.0000
# Epoch 21/25
# 500/500 [==============================] - 0s - loss: 0.1104 - acc: 1.0000
# Epoch 22/25
# 500/500 [==============================] - 0s - loss: 0.1013 - acc: 1.0000
# Epoch 23/25
# 500/500 [==============================] - 0s - loss: 0.0933 - acc: 1.0000
# Epoch 24/25
# 500/500 [==============================] - 0s - loss: 0.0869 - acc: 1.0000
# Epoch 25/25
# 500/500 [==============================] - 0s - loss: 0.0808 - acc: 1.0000

# %%
hor = np.linspace(-1.5, 1.5, 100)
ver = np.linspace(-1.5, 1.5, 100)
#print "hor-->", hor[0:20]
#print "ver-->", ver[0:20]
a, b = np.meshgrid(hor, ver)
#print "a-->", a[0:20]
#print "b-->", b[0:20]
a2b = np.c_[a.ravel(), b.ravel()]
#print "a2b-->", a2b
c = model.predict(a2b)
rc = c.reshape(a.shape)
#print "rc->shape", rc.shape

# %%
plt.figure(figsize=(8,8))
plt.contourf(a, b, rc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'og', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], '+r', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Green circles and red plus")
